# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
import pandas as pd

# %%
cd data
# Out:
# [WinError 2] The system cannot find the file specified: 'data'
# C:\Users\Jackson\Documents\flatiron\project1\dsc-phase-1-project-v3\data

# %%
aviation = pd.read_csv('Aviation_Data.csv')
# Out:
# C:\Users\Jackson\anaconda\anaconda-this one\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
aviation.head(30)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0   20001218X45444           Accident      SEA87LA080  1948-10-24
# 1   20001218X45447           Accident      LAX94LA336  1962-07-19
# 2   20061025X01555           Accident      NYC07LA005  1974-08-30
# 3   20001218X45448           Accident      LAX96LA321  1977-06-19
# 4   20041105X01764           Accident      CHI79FA064  1979-08-02
# 5   20170710X52551           Accident      NYC79AA106  1979-09-17
# 6   20001218X45446           Accident      CHI81LA106  1981-08-01
# 7   20020909X01562           Accident      SEA82DA022  1982-01-01
# 8   20020909X01561           Accident      NYC82DA015  1982-01-01
# 9   20020909X01560           Accident      MIA82DA029  1982-01-01
# 10  20020909X01559           Accident      FTW82DA034  1982-01-01
# 11  20020909X01558           Accident      ATL82DKJ10  1982-01-01
# 12  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# ...

# %%
aviation.info
# Out:
# <bound method DataFrame.info of              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
aviation.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
aviation['Total.Fatal.Injuries'].value_counts()
# Out:
# 0.0      59675
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 31.0         1
# 169.0        1
# 150.0        1
# 117.0        1
# 156.0        1
# Name: Total.Fatal.Injuries, Length: 125, dtype: int64

# %%
aviation['Investigation.Type'].value_counts()
# Out:
# Accident      85015
# Incident       3874
# 25-09-2020      702
# 26-09-2020       60
# 02-02-2021       39
#               ...
# 03-11-2020        1
# 11-02-2021        1
# 04-08-2021        1
# 18-11-2020        1
# 05-01-2021        1
# Name: Investigation.Type, Length: 71, dtype: int64

# %%
aviation.isna().sum()
# Out:
# Event.Id                   1459
# Investigation.Type            0
# Accident.Number            1459
# Event.Date                 1459
# Location                   1511
# Country                    1685
# Latitude                  55966
# Longitude                 55975
# Airport.Code              40099
# Airport.Name              37558
# Injury.Severity            2459
# Aircraft.damage            4653
# Aircraft.Category         58061
# Registration.Number        2776
# Make                       1522
# Model                      1551
# Amateur.Built              1561
# Number.of.Engines          7543
# Engine.Type                8536
# FAR.Description           58325
# Schedule                  77766
# Purpose.of.flight          7651
# Air.carrier               73700
# Total.Fatal.Injuries      12860
# Total.Serious.Injuries    13969
# Total.Minor.Injuries      13392
# Total.Uninjured            7371
# Weather.Condition          5951
# Broad.phase.of.flight     28624
# ...

# %%
duplicates = aviation[aviation.duplicated()]
print(len(duplicates))
duplicates
# Out:
# 1390
#       Event.Id Investigation.Type Accident.Number Event.Date Location Country  \
# 64050      NaN         25-09-2020             NaN        NaN      NaN     NaN
# 64052      NaN         25-09-2020             NaN        NaN      NaN     NaN
# 64388      NaN         25-09-2020             NaN        NaN      NaN     NaN
# 64541      NaN         25-09-2020             NaN        NaN      NaN     NaN
# 64552      NaN         25-09-2020             NaN        NaN      NaN     NaN
# ...        ...                ...             ...        ...      ...     ...
# 89956      NaN         15-12-2022             NaN        NaN      NaN     NaN
# 90004      NaN         15-12-2022             NaN        NaN      NaN     NaN
# 90010      NaN         15-12-2022             NaN        NaN      NaN     NaN
# 90031      NaN         15-12-2022             NaN        NaN      NaN     NaN
# 90097      NaN         20-12-2022             NaN        NaN      NaN     NaN
#
# ...

# %%
aviation_duplicates_dropped = aviation.drop_duplicates(subset='Event.Id')

# %%
aviation_duplicates_dropped.shape
# Out:
# (87952, 31)

# %%
aviation_duplicates_dropped['Investigation.Type'].value_counts()
# Out:
# Accident      84190
# Incident       3761
# 25-09-2020        1
# Name: Investigation.Type, dtype: int64

# %%
aviation_duplicates_dropped.loc[aviation_duplicates_dropped['Investigation.Type']== '25-09-2020']
# Out:
#       Event.Id Investigation.Type Accident.Number Event.Date Location Country  \
# 64030      NaN         25-09-2020             NaN        NaN      NaN     NaN
#
#       Latitude Longitude Airport.Code Airport.Name  ... Purpose.of.flight  \
# 64030      NaN       NaN          NaN          NaN  ...               NaN
#
#       Air.carrier Total.Fatal.Injuries Total.Serious.Injuries  \
# 64030         NaN                  NaN                    NaN
#
#       Total.Minor.Injuries Total.Uninjured Weather.Condition  \
# 64030                  NaN             NaN               NaN
#
#        Broad.phase.of.flight Report.Status Publication.Date
# 64030                    NaN           NaN              NaN
#
# [1 rows x 31 columns]

# %%
aviation_duplicates_dropped['Event.Id'].isna().sum()
# Out:
# 1

# %%
aviation_duplicates_dropped['Event.Id'].isna().sum()
# Out:
# 1

# %%
aviation_duplicates_dropped
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
aviation_duplicates_dropped.dropna(subset=['Event.Id'], inplace=True)
# Out:
# <ipython-input-87-736919b019a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_duplicates_dropped.dropna(subset=['Event.Id'], inplace=True)

# %%
aviation_duplicates_dropped['Event.Id'].isna().sum()
# Out:
# 0

# %%
aviation_cleaned = aviation_duplicates_dropped

# %%
aviation_cleaned['Investigation.Type'].value_counts()
# Out:
# Accident    84190
# Incident     3761
# Name: Investigation.Type, dtype: int64

# %%
incidents = aviation_cleaned.loc[aviation_cleaned['Investigation.Type'] == 'Incident']

# %%
aviation_cleaned['Total.Fatal.Injuries'] = aviation_cleaned['Total.Fatal.Injuries'].fillna(0)
# Out:
# <ipython-input-93-ce2beee0d01b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_cleaned['Total.Fatal.Injuries'] = aviation_cleaned['Total.Fatal.Injuries'].fillna(0)

# %%
aviation_cleaned['Total.Serious.Injuries'] = aviation_cleaned['Total.Serious.Injuries'].fillna(0)
# Out:
# <ipython-input-95-83abbc91f7b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_cleaned['Total.Serious.Injuries'] = aviation_cleaned['Total.Serious.Injuries'].fillna(0)

# %%
aviation_cleaned['Total.Minor.Injuries'] = aviation_cleaned['Total.Minor.Injuries'].fillna(0)
# Out:
# <ipython-input-97-1d78b4232cf6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_cleaned['Total.Minor.Injuries'] = aviation_cleaned['Total.Minor.Injuries'].fillna(0)

# %%
aviation_cleaned['Total Injuries'] = aviation_cleaned['Total.Fatal.Injuries'] + aviation_cleaned['Total.Serious.Injuries'] + aviation_cleaned['Total.Minor.Injuries']
# Out:
# <ipython-input-98-58919aeb48a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_cleaned['Total Injuries'] = aviation_cleaned['Total.Fatal.Injuries'] + aviation_cleaned['Total.Serious.Injuries'] + aviation_cleaned['Total.Minor.Injuries']

# %%
aviation_cleaned['Total Injuries'] = aviation_cleaned['Total.Fatal.Injuries'] + aviation_cleaned['Total.Serious.Injuries'] + aviation_cleaned['Total.Minor.Injuries']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\anaconda-this one\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Total.Fatal.Injuries'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-508e1f49e5ce> in <module>
# ...

# %%
aviation_cleaned.head(30)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0   20001218X45444           Accident      SEA87LA080  1948-10-24
# 1   20001218X45447           Accident      LAX94LA336  1962-07-19
# 2   20061025X01555           Accident      NYC07LA005  1974-08-30
# 3   20001218X45448           Accident      LAX96LA321  1977-06-19
# 4   20041105X01764           Accident      CHI79FA064  1979-08-02
# 5   20170710X52551           Accident      NYC79AA106  1979-09-17
# 6   20001218X45446           Accident      CHI81LA106  1981-08-01
# 7   20020909X01562           Accident      SEA82DA022  1982-01-01
# 8   20020909X01561           Accident      NYC82DA015  1982-01-01
# 9   20020909X01560           Accident      MIA82DA029  1982-01-01
# 10  20020909X01559           Accident      FTW82DA034  1982-01-01
# 11  20020909X01558           Accident      ATL82DKJ10  1982-01-01
# 12  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# ...

# %%
aviation_cleaned['Event.Date'].sort_values(ascending=False)
# Out:
# 90347    2022-12-29
# 90344    2022-12-26
# 90343    2022-12-26
# 90346    2022-12-26
# 90345    2022-12-26
#             ...
# 4        1979-08-02
# 3        1977-06-19
# 2        1974-08-30
# 1        1962-07-19
# 0        1948-10-24
# Name: Event.Date, Length: 87951, dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
aviation_cleaned['Purpose.of.flight'].value_counts()
# Out:
# Personal                     49076
# Instructional                10442
# Unknown                       6609
# Aerial Application            4686
# Business                      3971
# Positioning                   1632
# Other Work Use                1250
# Ferry                          806
# Aerial Observation             787
# Public Aircraft                710
# Executive/corporate            542
# Flight Test                    405
# Skydiving                      181
# External Load                  123
# Public Aircraft - Federal      104
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   53
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             5
# PUBS                             4
# PUBL                             1
# ...

# %%
x_flight_purpose = list(aviation_cleaned['Purpose.of.flight'].value_counts().index)
y_flight_purpose = list(aviation_cleaned['Purpose.of.flight'].value_counts().values)

# %%
fig, ax = plt.subplots(figsize=(30,8))

sns.barplot(x=x_flight_purpose, y=y_flight_purpose)

ax.set_title('Count of Flight Purposes')
ax.set_xlabel('Flight Purpose')
ax.set_ylabel('Number of Flights');

# %%
top_10_purposes = aviation_cleaned['Purpose.of.flight'].value_counts()[0:10]
top_10_purposes
# Out:
# Personal              49076
# Instructional         10442
# Unknown                6609
# Aerial Application     4686
# Business               3971
# Positioning            1632
# Other Work Use         1250
# Ferry                   806
# Aerial Observation      787
# Public Aircraft         710
# Name: Purpose.of.flight, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,8))

sns.barplot(x=top_10_purposes.index, y=top_10_purposes.values)

ax.set_title('Top 10 Flight Purposes - Accident Data')
ax.set_xlabel('Flight Purpose')
ax.set_ylabel('Number of Flights');

# %%
lowest_10_purposes = aviation_cleaned['Purpose.of.flight'].value_counts(ascending=True)[0:10]
lowest_10_purposes
# Out:
# PUBL                        1
# PUBS                        4
# ASHO                        5
# Air Drop                   11
# Firefighting               40
# Glider Tow                 53
# Air Race/show              53
# Public Aircraft - State    64
# Public Aircraft - Local    74
# Air Race show              99
# Name: Purpose.of.flight, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,8))

sns.barplot(x=lowest_10_purposes.index, y=lowest_10_purposes.values)

ax.set_title('Lowest 10 Reasons for Flight - Accident Data')
ax.set_xlabel('Flight Purpose')
ax.set_ylabel('Number of Flights');

# %%
fig, ax = plt.subplots(figsize=(30,8))

sns.barplot(x=aviation_cleaned['Purpose.of.flight'], y=aviation_cleaned['Total.Fatal.Injuries'])

ax.set_title('Purpose of Flight - Total Fatal Injuries')
ax.set_xlabel('Flight Purpose')
ax.set_ylabel('Total FATAL Injuries');

# %%
fig, ax = plt.subplots(figsize=(30,8))

sns.barplot(x=aviation_cleaned['Purpose.of.flight'], y=aviation_cleaned['Total Injuries'])

ax.set_title('Purpose of Flight - Total Injuries')
ax.set_xlabel('Flight Purpose')
ax.set_ylabel('Total Injuries');

# %%
aviation_cleaned['Purpose.of.flight'].value_counts()
# Out:
# Personal                     49076
# Instructional                10442
# Unknown                       6609
# Aerial Application            4686
# Business                      3971
# Positioning                   1632
# Other Work Use                1250
# Ferry                          806
# Aerial Observation             787
# Public Aircraft                710
# Executive/corporate            542
# Flight Test                    405
# Skydiving                      181
# External Load                  123
# Public Aircraft - Federal      104
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   53
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             5
# PUBS                             4
# PUBL                             1
# ...

# %%
personal = aviation_cleaned.loc[aviation_cleaned['Purpose.of.flight'] == 'Personal']

# %%
purposes = aviation_cleaned['Purpose.of.flight'].value_counts()
purposes
# Out:
# Personal                     49076
# Instructional                10442
# Unknown                       6609
# Aerial Application            4686
# Business                      3971
# Positioning                   1632
# Other Work Use                1250
# Ferry                          806
# Aerial Observation             787
# Public Aircraft                710
# Executive/corporate            542
# Flight Test                    405
# Skydiving                      181
# External Load                  123
# Public Aircraft - Federal      104
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   53
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             5
# PUBS                             4
# PUBL                             1
# ...

# %%
aviation_cleaned.groupby(['Purpose.of.flight','Total.Fatal.Injuries']).mean()
# Out:
#                                          Number.of.Engines  \
# Purpose.of.flight  Total.Fatal.Injuries
# ASHO               0.0                            1.000000
#                    1.0                            1.000000
#                    6.0                            1.000000
# Aerial Application 0.0                            1.001704
#                    1.0                            1.002237
# ...                                                    ...
# Unknown            228.0                          4.000000
#                    229.0                               NaN
#                    230.0                          4.000000
#                    256.0                          4.000000
#                    270.0                          4.000000
#
#                                          Total.Serious.Injuries  \
# Purpose.of.flight  Total.Fatal.Injuries
# ASHO               0.0                                 0.500000
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=aviation_cleaned['Number.of.Engines'], y=aviation_cleaned['Total.Fatal.Injuries'])

ax.set_title('Correlation of Fatal Injuries and # of Engines')
ax.set_xlabel('# of Engines')
ax.set_ylabel('Total Fatal Injuries');

# %%
personal.sort_values(by='Number.of.Engines')
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 31620  20001211X15868           Accident     FTW93LA010B  1992-10-08
# 31379  20001211X15618           Accident      BFO92LA130  1992-09-07
# 31472  20001211X15727           Accident      LAX92LA393  1992-09-18
# 10940  20001214X35738           Accident      LAX85LA153  1985-02-24
# 31517  20001211X15686           Accident      DEN92LA095  1992-09-24
# ...               ...                ...             ...         ...
# 90339  20221219106477           Accident      WPR23LA071  2022-12-18
# 90340  20221221106483           Accident      CEN23LA067  2022-12-21
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#                Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=personal['Number.of.Engines'], y=personal['Total.Fatal.Injuries'])

ax.set_title('Correlation of Fatal Injuries and # of Engines on Personal Aircrafts')
ax.set_xlabel('# of Engines')
ax.set_ylabel('Total Fatal Injuries');

# %%
personal['Number.of.Engines'].value_counts()
# Out:
# 1.0    43602
# 2.0     3229
# 0.0      745
# 4.0        9
# 3.0        4
# Name: Number.of.Engines, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(30,100))

sns.barplot(x=aviation_cleaned['Total.Fatal.Injuries'], y=aviation_cleaned['Country'], orient='h')

ax.set_title('Fatal Injuries Count by Country')
ax.set_xlabel('Total Fatal Injuries')
ax.set_ylabel('Country');

# %%
aviation_cleaned['Report.Status'].value_counts()
# Out:
# Probable Cause                                                                                                                                                                                                                                                         60867
# Foreign                                                                                                                                                                                                                                                                 1974
# <br /><br />                                                                                                                                                                                                                                                             167
# ...

# %%
aviation_cleaned['Broad.phase.of.flight'].value_counts()
# Out:
# Landing        15320
# Takeoff        12404
# Cruise         10141
# Maneuvering     8052
# Approach        6389
# Climb           1995
# Descent         1870
# Taxi            1786
# Go-around       1345
# Standing         872
# Unknown          547
# Other            116
# Name: Broad.phase.of.flight, dtype: int64

# %%
aviation_cleaned['Weather.Condition'].value_counts()
# Out:
# VMC    76417
# IMC     5949
# UNK      850
# Unk      262
# Name: Weather.Condition, dtype: int64

# %%
aviation_cleaned['Weather.Condition'] = aviation_cleaned['Weather.Condition'].replace('Unk', 'UNK')
# Out:
# <ipython-input-122-2c0ba9b0bc7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_cleaned['Weather.Condition'] = aviation_cleaned['Weather.Condition'].replace('Unk', 'UNK')

# %%
aviation_cleaned['Weather.Condition'].value_counts()
# Out:
# VMC    76417
# IMC     5949
# UNK     1112
# Name: Weather.Condition, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=aviation_cleaned['Number.of.Engines'], y=aviation_cleaned['Total.Uninjured'])

ax.set_title('Number of Engines and Total Uninjured')
ax.set_xlabel('# of Engines')
ax.set_ylabel('Total Uninjured');

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=aviation_cleaned['Weather.Condition'], y=aviation_cleaned['Total.Uninjured'])

ax.set_title('Weather Condition and Total Uninjured')
ax.set_xlabel('Weather Condition')
ax.set_ylabel('Total Uninjured');

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=aviation_cleaned['Weather.Condition'], y=aviation_cleaned['Total.Fatal.Injuries'])

ax.set_title('Weather Condition and Total Fatal Injuries')
ax.set_xlabel('Weather Condition')
ax.set_ylabel('Total Fatal Injuries');

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=aviation_cleaned['Weather.Condition'], y=aviation_cleaned['Total Injuries'])

ax.set_title('Weather Condition and Total Injuries')
ax.set_xlabel('Weather Condition')
ax.set_ylabel('Total Injuries');

# %%
aviation_cleaned['Total.Uninjured'] = aviation_cleaned['Total.Uninjured'].fillna(aviation_cleaned['Total.Uninjured'].mean())
# Out:
# <ipython-input-128-b8740e17e7b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_cleaned['Total.Uninjured'] = aviation_cleaned['Total.Uninjured'].fillna(aviation_cleaned['Total.Uninjured'].mean())

# %%
aviation_cleaned['Total.Uninjured'].mean()
# Out:
# 5.086638729168698

# %%
aviation_cleaned.head(30)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0   20001218X45444           Accident      SEA87LA080  1948-10-24
# 1   20001218X45447           Accident      LAX94LA336  1962-07-19
# 2   20061025X01555           Accident      NYC07LA005  1974-08-30
# 3   20001218X45448           Accident      LAX96LA321  1977-06-19
# 4   20041105X01764           Accident      CHI79FA064  1979-08-02
# 5   20170710X52551           Accident      NYC79AA106  1979-09-17
# 6   20001218X45446           Accident      CHI81LA106  1981-08-01
# 7   20020909X01562           Accident      SEA82DA022  1982-01-01
# 8   20020909X01561           Accident      NYC82DA015  1982-01-01
# 9   20020909X01560           Accident      MIA82DA029  1982-01-01
# 10  20020909X01559           Accident      FTW82DA034  1982-01-01
# 11  20020909X01558           Accident      ATL82DKJ10  1982-01-01
# 12  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# ...

# %%
aviation_cleaned.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date', 'Total Injuries',
#        'Ratio of Injured to Non-Injured'],
#       dtype='object')

# %%
aviation_cleaned['Ratio of Injured to Non-Injured'] = aviation_cleaned['Total Injuries'] / aviation_cleaned['Total.Uninjured']
# Out:
# <ipython-input-138-fafaa056edc1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_cleaned['Ratio of Injured to Non-Injured'] = aviation_cleaned['Total Injuries'] / aviation_cleaned['Total.Uninjured']

# %%
aviation_cleaned.head(30)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0   20001218X45444           Accident      SEA87LA080  1948-10-24
# 1   20001218X45447           Accident      LAX94LA336  1962-07-19
# 2   20061025X01555           Accident      NYC07LA005  1974-08-30
# 3   20001218X45448           Accident      LAX96LA321  1977-06-19
# 4   20041105X01764           Accident      CHI79FA064  1979-08-02
# 5   20170710X52551           Accident      NYC79AA106  1979-09-17
# 6   20001218X45446           Accident      CHI81LA106  1981-08-01
# 7   20020909X01562           Accident      SEA82DA022  1982-01-01
# 8   20020909X01561           Accident      NYC82DA015  1982-01-01
# 9   20020909X01560           Accident      MIA82DA029  1982-01-01
# 10  20020909X01559           Accident      FTW82DA034  1982-01-01
# 11  20020909X01558           Accident      ATL82DKJ10  1982-01-01
# 12  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=aviation_cleaned['Broad.phase.of.flight'], y=aviation_cleaned['Total Injuries'])

ax.set_title('Flight Phase of Accident and Total Injuries')
ax.set_xlabel('Flight Phase')
ax.set_ylabel('Total Injuries');

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x=aviation_cleaned['Broad.phase.of.flight'], y=aviation_cleaned['Total.Fatal.Injuries'])

ax.set_title('Flight Phase of Accident and Total Fatal Injuries')
ax.set_xlabel('Flight Phase')
ax.set_ylabel('Total Fatal Injuries');

# %%
aviation_cleaned.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date', 'Total Injuries',
#        'Ratio of Injured to Non-Injured'],
#       dtype='object')

# %%
aviation_cleaned['Engine.Type'].value_counts()
# Out:
# Reciprocating      68885
# Turbo Shaft         3583
# Turbo Prop          3324
# Turbo Fan           2387
# Unknown             2017
# Turbo Jet            684
# None                  19
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: Engine.Type, dtype: int64

# %%
aviation_cleaned.head(30)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0   20001218X45444           Accident      SEA87LA080  1948-10-24
# 1   20001218X45447           Accident      LAX94LA336  1962-07-19
# 2   20061025X01555           Accident      NYC07LA005  1974-08-30
# 3   20001218X45448           Accident      LAX96LA321  1977-06-19
# 4   20041105X01764           Accident      CHI79FA064  1979-08-02
# 5   20170710X52551           Accident      NYC79AA106  1979-09-17
# 6   20001218X45446           Accident      CHI81LA106  1981-08-01
# 7   20020909X01562           Accident      SEA82DA022  1982-01-01
# 8   20020909X01561           Accident      NYC82DA015  1982-01-01
# 9   20020909X01560           Accident      MIA82DA029  1982-01-01
# 10  20020909X01559           Accident      FTW82DA034  1982-01-01
# 11  20020909X01558           Accident      ATL82DKJ10  1982-01-01
# 12  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# ...

# %%
fig, ax = plt.subplots(figsize=(18,8))

sns.barplot(x=aviation_cleaned['Engine.Type'], y=aviation_cleaned['Total.Fatal.Injuries'])

ax.set_title('Engine Type and Total Fatal Injuries')
ax.set_xlabel('Engine Type')
ax.set_ylabel('Total Fatal Injuries');

# %%
fig, ax = plt.subplots(figsize=(18,8))

sns.barplot(x=aviation_cleaned['Engine.Type'], y=aviation_cleaned['Total Injuries'])

ax.set_title('Engine Type and Total Injuries')
ax.set_xlabel('Engine Type')
ax.set_ylabel('Total Injuries');

# %%
turbo_engines = aviation_cleaned.loc[(aviation_cleaned['Engine.Type'] == 'Turbo Fan') | (aviation_cleaned['Engine.Type'] == 'Turbo Jet')]

# %%
fig, ax = plt.subplots(figsize=(18,8))

sns.barplot(x=personal['Engine.Type'], y=personal['Total Injuries'])

ax.set_title('Engine Type and Total Injuries on Personal Flights')
ax.set_xlabel('Engine Type')
ax.set_ylabel('Total Injuries');

# %%
personal['Engine.Type'].value_counts()
# Out:
# Reciprocating    44863
# Unknown           1013
# Turbo Prop         483
# Turbo Shaft        349
# Turbo Fan           95
# Turbo Jet           85
# None                 7
# Electric             4
# NONE                 2
# Name: Engine.Type, dtype: int64

# %%
aviation_cleaned['Engine.Type'].value_counts()
# Out:
# Reciprocating      68885
# Turbo Shaft         3583
# Turbo Prop          3324
# Turbo Fan           2387
# Unknown             2017
# Turbo Jet            684
# None                  19
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: Engine.Type, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(18,8))

sns.barplot(x=personal['Number.of.Engines'], y=personal['Total Injuries'])

ax.set_title('# of Engines and Total Injuries on Personal Flights')
ax.set_xlabel('# of Engines')
ax.set_ylabel('Total Injuries');

# %%
fig, ax = plt.subplots(figsize=(18,8))

sns.barplot(x=personal['Number.of.Engines'], y=personal['Total.Fatal.Injuries'])

ax.set_title('# of Engines and Total Fatal Injuries on Personal Flights')
ax.set_xlabel('# of Engines')
ax.set_ylabel('Total Fatal Injuries');

# %%
personal['Number.of.Engines'].mean()
# Out:
# 1.0529324003446174

# %%
instructional = aviation_cleaned.loc[aviation_cleaned['Purpose.of.flight'] == 'Instructional']

# %%
instructional.head(30)
# Out:
#            Event.Id Investigation.Type Accident.Number  Event.Date  \
# 20   20020917X01894           Accident      CHI82FEC08  1982-01-02
# 48   20020917X01777           Accident      CHI82DA021  1982-01-06
# 57   20020917X02484           Accident      NYC82DA019  1982-01-08
# 58   20020917X02431           Accident      MKC82DA026  1982-01-08
# 59   20020917X01779           Accident      CHI82DA023  1982-01-08
# 61   20020917X01717           Accident      ATL82DLG09  1982-01-08
# 105  20020917X01624           Accident      ANC82DA014  1982-01-17
# 121  20020917X02488           Accident      NYC82DA024  1982-01-19
# 128  20020917X01781           Accident      CHI82DA028  1982-01-19
# 136  20020917X01998           Accident      FTW82DA044  1982-01-20
# 171  20020917X01652           Accident      ANC82FA017  1982-01-25
# 174  20020917X02430           Accident      MKC82DA025  1982-01-26
# 175  20020917X02427           Accident      MKC82DA021  1982-01-26
# ...

# %%
instructional['Number.of.Engines'].mean()
# Out:
# 1.0536470125012305

# %%
business = aviation_cleaned.loc[aviation_cleaned['Purpose.of.flight'] == 'Business']

# %%
business['Number.of.Engines'].mean()
# Out:
# 1.274540682414698

# %%
aviation_cleaned['Purpose.of.flight']
# Out:
# 0        Personal
# 1        Personal
# 2        Personal
# 3        Personal
# 4        Personal
#            ...
# 90343    Personal
# 90344         NaN
# 90345    Personal
# 90346    Personal
# 90347    Personal
# Name: Purpose.of.flight, Length: 87951, dtype: object

# %%
fig, ax = plt.subplots(figsize=(30,8))

sns.barplot(x=aviation_cleaned['Purpose.of.flight'], y=aviation_cleaned['Number.of.Engines'])

ax.set_title('# of Engines for Flight Purpose')
ax.set_xlabel('Flight Purpose')
ax.set_ylabel('# of Engines');

# %%
aviation_cleaned['Number.of.Engines'].max()
# Out:
# 8.0
